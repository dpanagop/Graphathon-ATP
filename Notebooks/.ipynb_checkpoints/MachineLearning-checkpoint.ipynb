# %%
# imports
from lib.ml_helper import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Preparation of the data for model building

# %% [markdown]
# #### Data loading

# %%
data = pd.read_csv("https://raw.githubusercontent.com/EY-Tech-Consulting-Denmark/Graphathon-ATP/main/Data/clean_data/data.csv")
data.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race  RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                      0     39
# 1  BENE17521  1913-12-01  NaN       2     1                      0     39
# 2  BENE21718  1922-10-01  NaN       1     1                      0     39
# 3  BENE22934  1930-07-01  NaN       2     1                      0     39
# 4  BENE24402  1925-09-01  NaN       2     2                      0     39
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     230                   12                   12                      1
# 2     600                   12                   12                      2
# 3     280                   12                   12                      2
# 4     510                   12                   12                      1
#
# ...

# %% [markdown]
# #### Features and target split

# %%
X = data[['RenalDiseaseIndicator', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
                                                          'ChronicCond_Cancer','ChronicCond_ObstrPulmonary', 'ChronicCond_Depression', 'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
                                                           'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke', 'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt', 
                                                          'OPAnnualReimbursementAmt','OPAnnualDeductibleAmt', 'InscClaimAmtReimbursed', 'DeductibleAmtPaid', 'Age', 'IsDead', 'DaysAdmitted',
                                                           'DaysClaimLasted', 'ClaimEndAfterDischarged', 'TotalDiagnosis',
                                                           'TotalProcedures', 'TotalPhysicians']]                                                   
y = data['PotentialFraud']

# %% [markdown]
# #### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                test_size=0.3, 
                                                random_state=1,
                                                shuffle=True)

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

# %% [markdown]
# ### Pipeline building

# %%
# Building a pipeline
lr_pipeline = Pipeline([['scaler', StandardScaler()], 
                        ['lr', LogisticRegression(random_state=45)]])

# %%
# Calculating roc_auc using 5-folds cross validation
lr_roc_auc_scores = cross_validate(lr_pipeline, X_train, y_train, metric='roc_auc')
# Out:
# The mean Roc AUC score is 0.5237153177332161 and the standard deviation is 0.0042024307621136335

# %%
# fitting of the pipeline
fitted_lr_pipeline = fit_pipeline(lr_pipeline, X_train, y_train)

# %%
features_coefficients = get_features_coefficients(fitted_lr_pipeline, X_train.columns)
features_coefficients
# Out:
#                            Features  Feature_coefficient
# 24          ClaimEndAfterDischarged             0.160505
# 26                  TotalProcedures             0.117023
# 18           InscClaimAmtReimbursed             0.032605
# 16         OPAnnualReimbursementAmt             0.019024
# 19                DeductibleAmtPaid             0.014774
# 9              ChronicCond_Diabetes             0.011766
# 14         IPAnnualReimbursementAmt             0.011480
# 23                  DaysClaimLasted             0.011086
# 25                   TotalDiagnosis             0.009547
# 15            IPAnnualDeductibleAmt             0.008319
# 10        ChronicCond_IschemicHeart             0.007989
# 20                              Age             0.006608
# 22                     DaysAdmitted             0.006342
# 2               NoOfMonths_PartBCov             0.004454
# 1               NoOfMonths_PartACov             0.002597
# ...

# %%
# evaluation on the test set
plot_confusion_matrix(fitted_lr_pipeline, X_test, y_test)
# Out:
# ROC AUC on provided set is:  0.5017896852750985
# F1 score on provided set is:  0.7298793021662362

# %% [markdown]
# ### Pipeline building utilizing graph features

# %% [markdown]
# ### Results comparison

# %%
# compare_pipelines(pipeline_names, cv_results)
